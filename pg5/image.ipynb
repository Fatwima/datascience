# %%
#Image Rotation
from PIL import Image
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
# %matplotlib inline
a=Image.open('a.jpg')
b=np.array(a)
c=ndimage.rotate(b,90,cval=110)
d=Image.fromarray(c)
d.save('b.jpg') 
plt.imshow(d)

# %%
#Image scaling
from PIL import Image
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
# %matplotlib inline


a=Image.open('a.jpg')
b=np.array(a)
c=ndimage.zoom(b,(.5,1,1))
d=Image.fromarray(c)
d.save('b.jpg')
plt.imshow(d)

# %%
#Image shearing
from PIL import Image
import numpy as np
from scipy import ndimage
from matplotlib import pyplot as plt
# %matplotlib inline


a=Image.open('a.jpg')
b=np.array(a)
h,w,c=b.shape
d=np.array([[1,0.5,0],[0.5,1,0],[0,0,1]])
c=ndimage.affine_transform(b,d)
plt.imshow(d)
